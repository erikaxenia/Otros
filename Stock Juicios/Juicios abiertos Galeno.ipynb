# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.options.display.float_format = '{:.3f}'.format

# %%
base = pd.read_csv(r'C:\Users\eangenello\Desktop\JYM_RAJ_ART_GALENO.csv', parse_dates = ['fecha_demanda'])
# Out:
# C:\Users\eangenello\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
base =  base[['ciaid', 'nro_raj', 'tipo_registro', 'juicio_mediacion', 'tipo_danio', 'fecha_demanda',
        'monto_indeterminado', 'monto_demandado', 'moneda','estado_procesal', 'acum_importes_honorarios_gastos',
        'acumu_importes_relacionado_monto', 'monto_reservado', 'ramo_subramo', 'nro_siniestro', 'nro_poliza']]

# %%
base
# Out:
#         ciaid  nro_raj  tipo_registro juicio_mediacion tipo_danio  \
# 0         619    48996              1                J          L
# 1         619    74002              1                J          L
# 2         619    52327              1                J          L
# 3         619    74646              1                J          L
# 4         619    49058              1                J          L
# 5         619    69622              1                J          L
# 6         619    69661              1                J          L
# 7         619    69658              1                J          L
# 8         619    49036              1                J          L
# 9         619    49047              1                J          L
# 10        619    49022              1                J          L
# 11        619    49003              1                J          L
# 12        619    49069              1                J          L
# ...

# %%
base.shape
# Out:
# (152775, 16)

# %%
base = base[(base['juicio_mediacion'] == 'J')]

# %%
base.shape
# Out:
# (152775, 16)

# %%
base['estado_procesal'].unique()
# Out:
# array([6, 7, 2, 4, 1, 3], dtype=int64)

# %%
base.groupby(['estado_procesal'], as_index=False)['ciaid'].count()
# Out:
#    estado_procesal  ciaid
# 0                1  39772
# 1                2  19003
# 2                3   4855
# 3                4   4309
# 4                6  11685
# 5                7  73151

# %%
base.groupby(['estado_procesal'], as_index=False)['monto_reservado'].sum()
# Out:
#    estado_procesal  monto_reservado
# 0                1       4872851989
# 1                2       6000310684
# 2                3       1811140804
# 3                4        295535477
# 4                6        822610347
# 5                7         36556345

# %%
base_stock = base[(base['estado_procesal'] == 1) | (base['estado_procesal'] == 2) | (base['estado_procesal'] == 3)]

# %%
base_stock.shape
# Out:
# (63630, 16)

# %%
base['raj_cia']= base['ciaid'].apply(lambda x: str(x)) + '-' + base['nro_raj'].apply(lambda x: str(x))
# Out:
# C:\Users\eangenello\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
len(base['raj_cia'].unique())
# Out:
# 8724

# %%
max(data_autom['fecha_demanda'])
# Out:
# Timestamp('2019-12-21 00:00:00')

# %%
data_autom[data_autom['fecha_demanda']>'2019-09-24']
# Out:
#        ciaid  nro_raj juicio_mediacion tipo_danio fecha_demanda  \
# 68574    348     4749                J          C    2019-12-21
#
#        monto_indeterminado  monto_demandado  estado_procesal  [1.030.00]  \
# 68574                    0       480000.000                1           1
#
#        [1.030.01]  [1.030.02]  [1.030.03]  [1.080.00]  [1.080.01]  [1.080.02]  \
# 68574           0           0           0           0           0           0
#
#        [1.080.03]  [1.080.04]  [1.080.99]  Juicios   raj_cia
# 68574           0           0           0        1  348-4749

# %%
a = data_autom.sort_values(['fecha_demanda'], ascending=True)
a = data_autom.reset_index()
a.head()
# Out:
#    index  ciaid  nro_raj juicio_mediacion tipo_danio fecha_demanda  \
# 0      1    222    70922                J          L    2018-12-07
# 1      2    222    70925                J          L    2018-12-07
# 2      3    222    70926                J         CL    2018-12-07
# 3      4    352    86970                J          C    2017-06-27
# 4      5    352    87068                J          C    2018-09-13
#
#    monto_indeterminado  monto_demandado  estado_procesal  [1.030.00]  \
# 0                    0      1448000.000                1           0
# 1                    0       645200.000                1           0
# 2                    0      1345488.000                1           0
# 3                    0        89341.000                1           0
# 4                    0        62715.000                1           0
#
#      ...      [1.030.02]  [1.030.03]  [1.080.00]  [1.080.01]  [1.080.02]  \
# ...

# %%
a.groupby()

# %%
a.groupby(['ciaid','nro_raj', 'Juicios'], as_index=False)['fecha_demanda'].max()
# Out:
#         ciaid  nro_raj  Juicios fecha_demanda
# 0           2     1365        1    2002-12-05
# 1           2     1867        1    2001-07-21
# 2           2     2346        1    2005-07-08
# 3           2     2726        1    2005-08-19
# 4           2     2993        1    2006-06-06
# 5           2     3014        1    2006-06-27
# 6           2     3240        1    2006-07-20
# 7           2     3300        1    2006-08-12
# 8           2     3328        1    2006-07-20
# 9           2     3369        1    2006-05-22
# 10          2     3376        1    2006-09-02
# 11          2     3551        1    2006-10-11
# 12          2     3563        1    2006-07-27
# 13          2     3569        1    2006-08-31
# 14          2     3665        1    2006-05-28
# 15          2     3667        1    2006-10-15
# 16          2     3805        1    2006-12-20
# 17          2     3865        1    2007-02-13
# 18          2     3917        1    2007-03-01
# ...

# %%
data_autom.shape

# %%
max(data_autom['fecha_demanda'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4a5521759687> in <module>()
# ----> 1 max(data_autom['fecha_demanda'])
#
# NameError: name 'data_autom' is not defined

# %%
ver = data_autom[data_autom['fecha_demanda']>'2019-06-30']
ver['sumar'] =1
# Out:
# C:\Users\eangenello\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
agrup_ver = ver.groupby(['ciaid'], as_index=False)['sumar'].sum()
agrup_ver
# Out:
#     ciaid  sumar
# 0      25    112
# 1      36      3
# 2      44      3
# 3     116    143
# 4     121     13
# 5     141      1
# 6     163     50
# 7     192     27
# 8     213     33
# 9     216     14
# 10    222    192
# 11    224     10
# 12    228      1
# 13    244     35
# 14    246      8
# 15    275      1
# 16    317     33
# 17    334      5
# 18    348      1
# 19    360     31
# 20    389     54
# 21    402     49
# 22    412      1
# 23    499     16
# 24    515     83
# 25    720     16
# 26    726    557
# 27    728      2
# 28    861      1

# %%
df.index.max()

# %%
data_atom.columns
# Out:
# Index(['ciaid', 'juicio_mediacion', 'tipo_danio', 'fecha_demanda',
#        'monto_indeterminado', 'monto_demandado', 'estado_procesal',
#        '[1.030.00]', '[1.030.01]', '[1.030.02]', '[1.030.03]', '[1.080.00]',
#        '[1.080.01]', '[1.080.02]', '[1.080.03]', '[1.080.04]', '[1.080.99]',
#        'ramo'],
#       dtype='object')

# %%
data_autom.groupby(['ciaid'], as_index=False)['Juicios'].sum()
# Out:
#     ciaid  Juicios
# 0       2     9476
# 1       6       17
# 2       7       14
# 3      11     1043
# 4      25    16473
# 5      32     6703
# 6      36    13336
# 7      39    19092
# 8      40     1394
# 9      44     2867
# 10     57      839
# 11     64      711
# 12     79     3520
# 13     80        2
# 14     96       23
# 15    116    16026
# 16    121     7797
# 17    136        1
# 18    141     3660
# 19    148      127
# 20    157     5844
# 21    163    14054
# 22    192    26573
# 23    196     1271
# 24    213    13829
# 25    216     4197
# 26    222    44785
# 27    224     8846
# 28    228      828
# 29    236       24
# ..    ...      ...
# 43    333      668
# 44    334      645
# 45    335     1744
# 46    348      699
# 47    352    43431
# 48    360     1366
# 49    363      388
# 50    381      139
# 51    388      193
# 52    389     8670
# 53    396        1
# 54    402     1720
# 55    406      498
# 56    412      240
# 57    415        5
# ...
